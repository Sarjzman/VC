# %%
import numpy as np

# %%
import pandas as pd

# %%
pd.read_csv('Cab_Data.csv')
# Out:
#         Transaction ID  Date of Travel     Company           City  \
# 0             10000011           42377    Pink Cab     ATLANTA GA
# 1             10000012           42375    Pink Cab     ATLANTA GA
# 2             10000013           42371    Pink Cab     ATLANTA GA
# 3             10000014           42376    Pink Cab     ATLANTA GA
# 4             10000015           42372    Pink Cab     ATLANTA GA
# ...                ...             ...         ...            ...
# 359387        10440101           43108  Yellow Cab  WASHINGTON DC
# 359388        10440104           43104  Yellow Cab  WASHINGTON DC
# 359389        10440105           43105  Yellow Cab  WASHINGTON DC
# 359390        10440106           43105  Yellow Cab  WASHINGTON DC
# 359391        10440107           43102  Yellow Cab  WASHINGTON DC
#
#         KM Travelled  Price Charged  Cost of Trip
# 0              30.45         370.95      313.6350
# 1              28.62         358.52      334.8540
# ...

# %%
Cab_Data=pd.read_csv('Cab_Data.csv')

# %%
# Load datasets
cab_data = pd.read_csv('Cab_Data.csv')
customer_id = pd.read_csv('Customer_ID.csv')
transaction_id = pd.read_csv('Transaction_ID.csv')
city_data = pd.read_csv('City.csv')

# Check structure and duplicates
print(cab_data.head())
print(cab_data.info())
print(cab_data.duplicated().sum())
# Out:
#    Transaction ID  Date of Travel   Company        City  KM Travelled  \
# 0        10000011           42377  Pink Cab  ATLANTA GA         30.45
# 1        10000012           42375  Pink Cab  ATLANTA GA         28.62
# 2        10000013           42371  Pink Cab  ATLANTA GA          9.04
# 3        10000014           42376  Pink Cab  ATLANTA GA         33.17
# 4        10000015           42372  Pink Cab  ATLANTA GA          8.73
#
#    Price Charged  Cost of Trip
# 0         370.95       313.635
# 1         358.52       334.854
# 2         125.20        97.632
# 3         377.40       351.602
# 4         114.62        97.776
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 359392 entries, 0 to 359391
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Transaction ID  359392 non-null  int64
#  1   Date of Travel  359392 non-null  int64
#  2   Company         359392 non-null  object
# ...

# %%
# Check for duplicates
print(cab_data.duplicated().sum())

# Remove duplicates
cab_data = cab_data.drop_duplicates()
# Out:
# 0

# %%
# Print columns in each dataset
print("Cab_Data columns:")
print(cab_data.columns)

print("\nCustomer_ID columns:")
print(customer_id.columns)

print("\nTransaction_ID columns:")
print(transaction_id.columns)

print("\nCity columns:")
print(city_data.columns)
# Out:
# Cab_Data columns:
# Index(['Transaction ID', 'Date of Travel', 'Company', 'City', 'KM Travelled',
#        'Price Charged', 'Cost of Trip'],
#       dtype='object')
#
# Customer_ID columns:
# Index(['Customer ID', 'Gender', 'Age', 'Income (USD/Month)'], dtype='object')
#
# Transaction_ID columns:
# Index(['Transaction ID', 'Customer ID', 'Payment_Mode'], dtype='object')
#
# City columns:
# Index(['City', 'Population', 'Users'], dtype='object')

# %%
# Join cab_data and transaction_id on 'Transaction ID'
joined_cab_transaction = cab_data.join(transaction_id.set_index('Transaction ID'), on='Transaction ID', how='inner')

# Print columns in the joined dataset
print("Joined cab_transaction dataset columns:")
print(joined_cab_transaction.columns)

# Check the shape of the joined dataset
print("Shape of joined_cab_transaction:", joined_cab_transaction.shape)
# Out:
# Joined cab_transaction dataset columns:
# Index(['Transaction ID', 'Date of Travel', 'Company', 'City', 'KM Travelled',
#        'Price Charged', 'Cost of Trip', 'Customer ID', 'Payment_Mode'],
#       dtype='object')
# Shape of joined_cab_transaction: (359392, 9)

# %%
joined_cab_transaction
# Out:
#         Transaction ID  Date of Travel     Company           City  \
# 0             10000011           42377    Pink Cab     ATLANTA GA
# 1             10000012           42375    Pink Cab     ATLANTA GA
# 2             10000013           42371    Pink Cab     ATLANTA GA
# 3             10000014           42376    Pink Cab     ATLANTA GA
# 4             10000015           42372    Pink Cab     ATLANTA GA
# ...                ...             ...         ...            ...
# 359387        10440101           43108  Yellow Cab  WASHINGTON DC
# 359388        10440104           43104  Yellow Cab  WASHINGTON DC
# 359389        10440105           43105  Yellow Cab  WASHINGTON DC
# 359390        10440106           43105  Yellow Cab  WASHINGTON DC
# 359391        10440107           43102  Yellow Cab  WASHINGTON DC
#
#         KM Travelled  Price Charged  Cost of Trip  Customer ID Payment_Mode
# 0              30.45         370.95      313.6350        29290         Card
# ...

# %%
cab_data
# Out:
#         Transaction ID  Date of Travel     Company           City  \
# 0             10000011           42377    Pink Cab     ATLANTA GA
# 1             10000012           42375    Pink Cab     ATLANTA GA
# 2             10000013           42371    Pink Cab     ATLANTA GA
# 3             10000014           42376    Pink Cab     ATLANTA GA
# 4             10000015           42372    Pink Cab     ATLANTA GA
# ...                ...             ...         ...            ...
# 359387        10440101           43108  Yellow Cab  WASHINGTON DC
# 359388        10440104           43104  Yellow Cab  WASHINGTON DC
# 359389        10440105           43105  Yellow Cab  WASHINGTON DC
# 359390        10440106           43105  Yellow Cab  WASHINGTON DC
# 359391        10440107           43102  Yellow Cab  WASHINGTON DC
#
#         KM Travelled  Price Charged  Cost of Trip
# 0              30.45         370.95      313.6350
# 1              28.62         358.52      334.8540
# ...

# %%
customer_id
# Out:
#        Customer ID  Gender  Age  Income (USD/Month)
# 0            29290    Male   28               10813
# 1            27703    Male   27                9237
# 2            28712    Male   53               11242
# 3            28020    Male   23               23327
# 4            27182    Male   33                8536
# ...            ...     ...  ...                 ...
# 49166        12490    Male   33               18713
# 49167        14971    Male   30               15346
# 49168        41414    Male   38                3960
# 49169        41677    Male   23               19454
# 49170        39761  Female   32               10128
#
# [49171 rows x 4 columns]

# %%
transaction_id
# Out:
#         Transaction ID  Customer ID Payment_Mode
# 0             10000011        29290         Card
# 1             10000012        27703         Card
# 2             10000013        28712         Cash
# 3             10000014        28020         Cash
# 4             10000015        27182         Card
# ...                ...          ...          ...
# 440093        10440104        53286         Cash
# 440094        10440105        52265         Cash
# 440095        10440106        52175         Card
# 440096        10440107        52917         Card
# 440097        10440108        51587         Card
#
# [440098 rows x 3 columns]

# %%
joined_cab_transaction
# Out:
#         Transaction ID  Date of Travel     Company           City  \
# 0             10000011           42377    Pink Cab     ATLANTA GA
# 1             10000012           42375    Pink Cab     ATLANTA GA
# 2             10000013           42371    Pink Cab     ATLANTA GA
# 3             10000014           42376    Pink Cab     ATLANTA GA
# 4             10000015           42372    Pink Cab     ATLANTA GA
# ...                ...             ...         ...            ...
# 359387        10440101           43108  Yellow Cab  WASHINGTON DC
# 359388        10440104           43104  Yellow Cab  WASHINGTON DC
# 359389        10440105           43105  Yellow Cab  WASHINGTON DC
# 359390        10440106           43105  Yellow Cab  WASHINGTON DC
# 359391        10440107           43102  Yellow Cab  WASHINGTON DC
#
#         KM Travelled  Price Charged  Cost of Trip  Customer ID Payment_Mode
# 0              30.45         370.95      313.6350        29290         Card
# ...

# %%
# Print columns in the customer_id DataFrame
print("Columns in customer_id:", customer_id.columns)
# Out:
# Columns in customer_id: Index(['Customer ID', 'Gender', 'Age', 'Income (USD/Month)'], dtype='object')

# %%
customer_id
# Out:
#        Customer ID  Gender  Age  Income (USD/Month)
# 0            29290    Male   28               10813
# 1            27703    Male   27                9237
# 2            28712    Male   53               11242
# 3            28020    Male   23               23327
# 4            27182    Male   33                8536
# ...            ...     ...  ...                 ...
# 49166        12490    Male   33               18713
# 49167        14971    Male   30               15346
# 49168        41414    Male   38                3960
# 49169        41677    Male   23               19454
# 49170        39761  Female   32               10128
#
# [49171 rows x 4 columns]

# %%
customer_id.drop(columns=['Customer ID'], inplace=True)
final_joined_data = joined_cab_transaction.join(customer_id, on='Customer ID', how='inner')

# %%
final_joined_data
# Out:
#         Transaction ID  Date of Travel     Company            City  \
# 0             10000011           42377    Pink Cab      ATLANTA GA
# 285625        10351127           43302  Yellow Cab      ATLANTA GA
# 336890        10412921           43427  Yellow Cab      ATLANTA GA
# 1             10000012           42375    Pink Cab      ATLANTA GA
# 261229        10320494           43211  Yellow Cab      ATLANTA GA
# ...                ...             ...         ...             ...
# 359114        10439790           43107  Yellow Cab      SEATTLE WA
# 359123        10439799           43103  Yellow Cab  SILICON VALLEY
# 359155        10439838           43104  Yellow Cab       TUCSON AZ
# 359157        10439840           43106  Yellow Cab       TUCSON AZ
# 359163        10439846           43104  Yellow Cab       TUCSON AZ
#
#         KM Travelled  Price Charged  Cost of Trip  Customer ID Payment_Mode  \
# 0              30.45         370.95      313.6350        29290         Card
# ...

# %%
final_joined_data = final_joined_data.join(city_data.set_index('City'), on='City', how='inner')

# %%
final_joined_data
# Out:
#         Transaction ID  Date of Travel     Company        City  KM Travelled  \
# 0             10000011           42377    Pink Cab  ATLANTA GA         30.45
# 285625        10351127           43302  Yellow Cab  ATLANTA GA         26.19
# 336890        10412921           43427  Yellow Cab  ATLANTA GA         42.55
# 1             10000012           42375    Pink Cab  ATLANTA GA         28.62
# 261229        10320494           43211  Yellow Cab  ATLANTA GA         36.38
# ...                ...             ...         ...         ...           ...
# 357421        10437576           43105    Pink Cab   TUCSON AZ         35.96
# 357424        10437582           43105    Pink Cab   TUCSON AZ         31.35
# 359155        10439838           43104  Yellow Cab   TUCSON AZ         19.00
# 359157        10439840           43106  Yellow Cab   TUCSON AZ          5.60
# 359163        10439846           43104  Yellow Cab   TUCSON AZ         13.30
#
# ...

# %%
# Create a 'Profit' column
final_joined_data['Profit'] = final_joined_data['Price Charged'] - final_joined_data['Cost of Trip']

# Display the updated DataFrame with the new 'Profit' column
print(final_joined_data.head())
# Out:
#         Transaction ID  Date of Travel     Company        City  KM Travelled  \
# 0             10000011           42377    Pink Cab  ATLANTA GA         30.45
# 285625        10351127           43302  Yellow Cab  ATLANTA GA         26.19
# 336890        10412921           43427  Yellow Cab  ATLANTA GA         42.55
# 1             10000012           42375    Pink Cab  ATLANTA GA         28.62
# 261229        10320494           43211  Yellow Cab  ATLANTA GA         36.38
#
#         Price Charged  Cost of Trip  Customer ID Payment_Mode  Gender  Age  \
# 0              370.95      313.6350        29290         Card    Male   47
# 285625         598.70      317.4228        29290         Cash    Male   47
# 336890         792.05      597.4020        29290         Card    Male   47
# 1              358.52      334.8540        27703         Card  Female   36
# 261229         721.10      467.1192        27703         Card  Female   36
#
# ...

# %%
final_joined_data
# Out:
#         Transaction ID  Date of Travel     Company        City  KM Travelled  \
# 0             10000011           42377    Pink Cab  ATLANTA GA         30.45
# 285625        10351127           43302  Yellow Cab  ATLANTA GA         26.19
# 336890        10412921           43427  Yellow Cab  ATLANTA GA         42.55
# 1             10000012           42375    Pink Cab  ATLANTA GA         28.62
# 261229        10320494           43211  Yellow Cab  ATLANTA GA         36.38
# ...                ...             ...         ...         ...           ...
# 357421        10437576           43105    Pink Cab   TUCSON AZ         35.96
# 357424        10437582           43105    Pink Cab   TUCSON AZ         31.35
# 359155        10439838           43104  Yellow Cab   TUCSON AZ         19.00
# 359157        10439840           43106  Yellow Cab   TUCSON AZ          5.60
# 359163        10439846           43104  Yellow Cab   TUCSON AZ         13.30
#
# ...

# %%
# Define age bins and labels
age_bins = [0, 30, 60, float('inf')]
age_labels = ['Young', 'Middle Aged', 'Old']

# Create a new column 'Age Group' based on age bins
final_joined_data['Age Group'] = pd.cut(final_joined_data['Age'], bins=age_bins, labels=age_labels, right=False)

# %%
final_joined_data
# Out:
#         Transaction ID                Date of Travel     Company        City  \
# 0             10000011 1970-01-01 00:00:00.000042377    Pink Cab  ATLANTA GA
# 285625        10351127 1970-01-01 00:00:00.000043302  Yellow Cab  ATLANTA GA
# 336890        10412921 1970-01-01 00:00:00.000043427  Yellow Cab  ATLANTA GA
# 1             10000012 1970-01-01 00:00:00.000042375    Pink Cab  ATLANTA GA
# 261229        10320494 1970-01-01 00:00:00.000043211  Yellow Cab  ATLANTA GA
# ...                ...                           ...         ...         ...
# 357421        10437576 1970-01-01 00:00:00.000043105    Pink Cab   TUCSON AZ
# 357424        10437582 1970-01-01 00:00:00.000043105    Pink Cab   TUCSON AZ
# 359155        10439838 1970-01-01 00:00:00.000043104  Yellow Cab   TUCSON AZ
# 359157        10439840 1970-01-01 00:00:00.000043106  Yellow Cab   TUCSON AZ
# 359163        10439846 1970-01-01 00:00:00.000043104  Yellow Cab   TUCSON AZ
#
# ...

# %%
# Group by 'Company' and count the unique 'Transaction ID's
total_transactions_by_company = final_joined_data.groupby('Company')['Transaction ID'].nunique()

# Display the result
print("Total number of unique Transaction IDs for each company:")
print(total_transactions_by_company)
# Out:
# Total number of unique Transaction IDs for each company:
# Company
# Pink Cab       73602
# Yellow Cab    208591
# Name: Transaction ID, dtype: int64

# %%
# Group by 'Company' and calculate the average 'Profit'
average_profit_by_company = final_joined_data.groupby('Company')['Profit'].mean()

# Display the result
print("Average Profit for Pink Cab:", average_profit_by_company.get('Pink Cab', 0))
print("Average Profit for Yellow Cab:", average_profit_by_company.get('Yellow Cab', 0))
# Out:
# Average Profit for Pink Cab: 64.90219549740496
# Average Profit for Yellow Cab: 187.40039586751107

# %%
final_joined_data.columns
# Out:
# Index(['Transaction ID', 'Date of Travel', 'Company', 'City', 'KM Travelled',
#        'Price Charged', 'Cost of Trip', 'Customer ID', 'Payment_Mode',
#        'Gender', 'Age', 'Income (USD/Month)', 'Population', 'Users', 'Profit',
#        'Age Group'],
#       dtype='object')

# %%
# Group by 'Company' and 'City' and calculate the average 'Profit'
average_profit_by_city = final_joined_data.groupby(['Company', 'City'])['Profit'].mean().reset_index()

# Display the result
print("Average Profit per City for both cabs:")
print(average_profit_by_city)
# Out:
# Average Profit per City for both cabs:
#        Company            City      Profit
# 0     Pink Cab      ATLANTA GA   54.511961
# 1     Pink Cab       AUSTIN TX   78.932168
# 2     Pink Cab      CHICAGO IL   34.047910
# 3     Pink Cab       DALLAS TX   17.920371
# 4     Pink Cab       DENVER CO   29.114016
# 5     Pink Cab  LOS ANGELES CA   56.669120
# 6     Pink Cab        MIAMI FL   81.069526
# 7     Pink Cab     NEW YORK NY  108.217540
# 8     Pink Cab   ORANGE COUNTY   67.412976
# 9     Pink Cab      PHOENIX AZ   41.199530
# 10    Pink Cab   PITTSBURGH PA   23.162312
# 11    Pink Cab   SACRAMENTO CA   41.472273
# 12    Pink Cab    SAN DIEGO CA   59.772280
# 13    Pink Cab      SEATTLE WA   41.281601
# 14    Pink Cab  SILICON VALLEY   89.610358
# 15    Pink Cab       TUCSON AZ   74.204725
# 16  Yellow Cab      ATLANTA GA  128.797723
# 17  Yellow Cab       AUSTIN TX  125.249582
# 18  Yellow Cab      CHICAGO IL   64.924486
# 19  Yellow Cab       DALLAS TX  195.849415
# ...

# %%
# Visualize profitability by cab company using a bar plot
plt.figure(figsize=(12, 6))
sns.barplot(x='Company', y='Profit', data=final_joined_data, ci=None)
plt.title('Profitability by Cab Company')
plt.xlabel('Cab Company')
plt.ylabel('Profit')
plt.savefig('Profitability by Cab Company.png')
plt.show()
# Out:
# Current Working Directory: C:\Users\Admin\Desktop\week 2 assigments

# %%
# Visualize customer segmentation based on existing age groups using histograms
plt.figure(figsize=(12, 6))
sns.histplot(x='Age Group', data=final_joined_data, bins=20, hue='Company', multiple='stack')
plt.title('Customer Segmentation Based on Age Groups')
plt.xlabel('Age Group')
plt.ylabel('Number of Customers')
plt.savefig('Customer Segmentation Based on Age Groups.png')
plt.show()

# %%
# Visualize profitability by city for both companies using a bar plot
plt.figure(figsize=(16, 8))
sns.barplot(x='City', y='Profit', data=final_joined_data, hue='Company', ci=None)
plt.title('Profitability Variation by City for Both Companies')
plt.xlabel('City')
plt.ylabel('Profit')
plt.xticks(rotation=45, ha='right')
plt.savefig('Profitability Variation by City for Both Companies.png')
plt.show()

# %%
# Visualize customer distribution by gender using a bar plot
plt.figure(figsize=(10, 6))
sns.countplot(x='Gender', data=final_joined_data, hue='Company')
plt.title('Customer Distribution by Gender')
plt.xlabel('Gender')
plt.ylabel('Number of Customers')
plt.savefig('Customer distribution by gender.png')
plt.show()

# %%
# Visualize the relationship between age group and profit using a bar plot
plt.figure(figsize=(12, 6))
sns.barplot(x='Age Group', y='Profit', data=final_joined_data, hue='Company', ci=None)
plt.title('Relationship Between Age Group and Profit for Both Companies')
plt.xlabel('Age Group')
plt.ylabel('Profit')
plt.savefig('Relationship between Age group and profit.png')
plt.show()

# %%
# Create a bar plot to compare average profitability and average distance traveled for both companies
plt.figure(figsize=(12, 6))

# Bar plot for average profitability
sns.barplot(x='Company', y='Profit', data=avg_profit_distance, ci=None, label='Profit', color='skyblue')
# Bar plot for average distance traveled
sns.barplot(x='Company', y='KM Travelled', data=avg_profit_distance, ci=None, label='Distance Traveled', color='salmon')

plt.title('Comparison of Average Profitability and Average Distance Traveled for Both Companies')
plt.xlabel('Company')
plt.ylabel('Average Value')
plt.legend()
plt.savefig('Comparison of Average Profitability and Average Distance Traveled for Both Companies.png')
plt.show()

# %%
# Create a grouped bar plot to compare profit based on payment mode for both companies
plt.figure(figsize=(12, 6))

# Grouped bar plot for Pink Cab
sns.barplot(x='Payment_Mode', y='Profit', data=final_joined_data[final_joined_data['Company'] == 'Pink Cab'], ci=None, label='Pink Cab', color='black')
# Grouped bar plot for Yellow Cab
sns.barplot(x='Payment_Mode', y='Profit', data=final_joined_data[final_joined_data['Company'] == 'Yellow Cab'], ci=None, label='Yellow Cab', color='red', alpha=0.7)

plt.title('Customer Satisfaction (Profit) Based on Payment Mode for Both Companies')
plt.xlabel('Payment Mode')
plt.ylabel('Profit')
plt.legend()
plt.savefig('Customer Satisfaction (Profit) Based on Payment Mode for Both Companies.png')
plt.show()

# %%
# Create income groups
income_bins = [0, 12500, 25000, 37500, 50000]
income_labels = ['0-12.5k', '12.5k-25k', '25k-37.5k', '37.5k-50k']
final_joined_data['Income_Group'] = pd.cut(final_joined_data['Income (USD/Month)'], bins=income_bins, labels=income_labels, right=False)

# Create a bar plot to visualize profitability based on the updated income groups for both companies
plt.figure(figsize=(14, 8))
sns.barplot(x='Income_Group', y='Profit', hue='Company', data=final_joined_data, ci=None)
plt.title('Profitability Based on Income Group (0-50k) for Both Companies')
plt.xlabel('Income Group')
plt.ylabel('Profit')
plt.legend(title='Company')
plt.savefig('Profitability Based on Income Group (0-50k) for Both Companies.png')
plt.show()

# %%
# Create a bar plot to visualize total kilometers traveled for both companies
plt.figure(figsize=(14, 8))
sns.barplot(x='Company', y='KM Travelled', data=final_joined_data.groupby('Company')['KM Travelled'].sum().reset_index())
plt.title('Total Kilometers Traveled for Both Companies')
plt.xlabel('Company')
plt.ylabel('Total KM Travelled')
plt.savefig('Total Kilometers Traveled for Both Companies.png')
plt.show()

# %%
# Calculate average profit per kilometer for each company
final_joined_data['Avg_Profit_Per_KM'] = final_joined_data['Profit'] / final_joined_data['KM Travelled']

# Create a bar plot to visualize average profit per kilometer for both companies
plt.figure(figsize=(14, 8))
sns.barplot(x='Company', y='Avg_Profit_Per_KM', data=final_joined_data.groupby('Company')['Avg_Profit_Per_KM'].mean().reset_index())
plt.title('Average Profit per Kilometer for Both Companies')
plt.xlabel('Company')
plt.ylabel('Average Profit per KM')
plt.savefig('Average Profit per Kilometer for Both Companies.png')
plt.show()

# %%
# Unique customer IDs for Pink Cab
unique_customers_pink = set(final_joined_data[final_joined_data['Company'] == 'Pink Cab']['Customer ID'])
print("Unique Customer IDs for Pink Cab:", len(unique_customers_pink))

# Unique customer IDs for Yellow Cab
unique_customers_yellow = set(final_joined_data[final_joined_data['Company'] == 'Yellow Cab']['Customer ID'])
print("Unique Customer IDs for Yellow Cab:", len(unique_customers_yellow))
# Out:
# Unique Customer IDs for Pink Cab: 26052
# Unique Customer IDs for Yellow Cab: 32600

# %%
# Unique customer IDs for Pink Cab
unique_customers_pink = set(final_joined_data[final_joined_data['Company'] == 'Pink Cab']['Customer ID'])

# Unique customer IDs for Yellow Cab
unique_customers_yellow = set(final_joined_data[final_joined_data['Company'] == 'Yellow Cab']['Customer ID'])

# Find common customer IDs
common_customers = unique_customers_pink.intersection(unique_customers_yellow)

# Get the total number of common customers
total_common_customers = len(common_customers)

print("Total number of customers who patronize both Pink Cab and Yellow Cab:", total_common_customers)
# Out:
# Total number of customers who patronize both Pink Cab and Yellow Cab: 20997

# %%
# Filter data for common customers
common_customers_data = final_joined_data[final_joined_data['Customer ID'].isin(common_customers)]

# Count the occurrences of each cab for common customers
cab_usage_counts = common_customers_data['Company'].value_counts()

# Print the counts
print("Cab Usage Counts for Common Customers:")
print(cab_usage_counts)

# Determine the cab used more by common customers
preferred_cab = cab_usage_counts.idxmax()
print("\nPreferred Cab for Common Customers:", preferred_cab)
# Out:
# Cab Usage Counts for Common Customers:
# Yellow Cab    185308
# Pink Cab       66730
# Name: Company, dtype: int64
#
# Preferred Cab for Common Customers: Yellow Cab

# %%
# Group the data by 'Customer ID' and 'Company' and calculate the average income
avg_income_by_customer = final_joined_data.groupby(['Customer ID', 'Company'])['Income (USD/Month)'].mean().reset_index()

# Print the result
print("Average Income of Each Customer for Each Cab:")
print(avg_income_by_customer)
# Out:
# Average Income of Each Customer for Each Cab:
#        Customer ID     Company  Income (USD/Month)
# 0                1    Pink Cab              9237.0
# 1                1  Yellow Cab              9237.0
# 2                2    Pink Cab             11242.0
# 3                2  Yellow Cab             11242.0
# 4                3    Pink Cab             23327.0
# ...            ...         ...                 ...
# 58647        49165    Pink Cab             19417.0
# 58648        49165  Yellow Cab             19417.0
# 58649        49166  Yellow Cab             18713.0
# 58650        49167    Pink Cab             15346.0
# 58651        49169  Yellow Cab             19454.0
#
# [58652 rows x 3 columns]

# %%
# Filter the DataFrame for Pink Cab
pink_cab_avg_income = avg_income_by_customer[avg_income_by_customer['Company'] == 'Pink Cab']

# Calculate the average income for Pink Cab customers
avg_income_pink_cab = pink_cab_avg_income['Income (USD/Month)'].mean()

# Print the result
print("Average Income of Pink Cab Customers:", avg_income_pink_cab)
# Out:
# Average Income of Pink Cab Customers: 15047.949715952709

# %%
# Filter the DataFrame for Yellow Cab
yellow_cab_avg_income = avg_income_by_customer[avg_income_by_customer['Company'] == 'Yellow Cab']

# Calculate the average income for Yellow Cab customers
avg_income_yellow_cab = yellow_cab_avg_income['Income (USD/Month)'].mean()

# Print the result
print("Average Income of Yellow Cab Customers:", avg_income_yellow_cab)
# Out:
# Average Income of Yellow Cab Customers: 15014.590398773005

# %%
print(final_joined_data[['Users', 'Population']].dtypes)
# Out:
# Users         float64
# Population    float64
# dtype: object

# %%
final_joined_data['Users'] = pd.to_numeric(final_joined_data['Users'], errors='coerce')
final_joined_data['Population'] = pd.to_numeric(final_joined_data['Population'], errors='coerce')

# %%
print(final_joined_data[['Users', 'Population']].isnull().sum())
# Out:
# Users         282193
# Population    282193
# dtype: int64

# %%
print(final_joined_data[['Users', 'Population']].head())
# Out:
#         Users  Population
# 0         NaN         NaN
# 285625    NaN         NaN
# 336890    NaN         NaN
# 1         NaN         NaN
# 261229    NaN         NaN

# %%
final_joined_data
# Out:
#         Transaction ID                Date of Travel     Company        City  \
# 0             10000011 1970-01-01 00:00:00.000042377    Pink Cab  ATLANTA GA
# 285625        10351127 1970-01-01 00:00:00.000043302  Yellow Cab  ATLANTA GA
# 336890        10412921 1970-01-01 00:00:00.000043427  Yellow Cab  ATLANTA GA
# 1             10000012 1970-01-01 00:00:00.000042375    Pink Cab  ATLANTA GA
# 261229        10320494 1970-01-01 00:00:00.000043211  Yellow Cab  ATLANTA GA
# ...                ...                           ...         ...         ...
# 357421        10437576 1970-01-01 00:00:00.000043105    Pink Cab   TUCSON AZ
# 357424        10437582 1970-01-01 00:00:00.000043105    Pink Cab   TUCSON AZ
# 359155        10439838 1970-01-01 00:00:00.000043104  Yellow Cab   TUCSON AZ
# 359157        10439840 1970-01-01 00:00:00.000043106  Yellow Cab   TUCSON AZ
# 359163        10439846 1970-01-01 00:00:00.000043104  Yellow Cab   TUCSON AZ
#
# ...

# %%
print(final_joined_data['Quarter'].unique())
# Out:
# <PeriodArray>
# ['1970Q1']
# Length: 1, dtype: period[Q-DEC]

# %%
# Group by 'City' and count the number of unique transactions
transactions_per_city = final_joined_data.groupby('City')['Transaction ID'].nunique()

# Find the city with the highest number of transactions
city_with_highest_transactions = transactions_per_city.idxmax()

# Print the result
print("City with the highest number of transactions:", city_with_highest_transactions)
# Out:
# City with the highest number of transactions: NEW YORK NY

# %%
# Filter the data for New York, NY
ny_transactions = final_joined_data[final_joined_data['City'] == 'NEW YORK NY']

# Count the number of transactions for each cab company
transactions_count = ny_transactions.groupby('Company')['Transaction ID'].count()
print(transactions_count)
# Out:
# Company
# Pink Cab      13967
# Yellow Cab    85918
# Name: Transaction ID, dtype: int64

# %%
# Calculate the average profit for each cab company
average_profit = ny_transactions.groupby('Company')['Profit'].mean()
print(average_profit)
# Out:
# Company
# Pink Cab      108.217540
# Yellow Cab    307.864252
# Name: Profit, dtype: float64

# %%
# Find the city with the lowest number of transactions
lowest_transactions_city = final_joined_data.groupby('City')['Transaction ID'].count().idxmin()

# Filter the data for the city with the lowest transactions
lowest_transactions_data = final_joined_data[final_joined_data['City'] == lowest_transactions_city]

# %%
lowest_transactions_city
# Out:
# 'PITTSBURGH PA'

# %%
# Count the number of transactions for each cab company in the city with the lowest transactions
lowest_transactions_count = lowest_transactions_data.groupby('Company')['Transaction ID'].count()
print(lowest_transactions_count)
# Out:
# Company
# Pink Cab      292
# Yellow Cab    261
# Name: Transaction ID, dtype: int64

# %%
# Calculate the average profit for each cab company in the city with the lowest transactions
lowest_transactions_average_profit = lowest_transactions_data.groupby('Company')['Profit'].mean()
print(lowest_transactions_average_profit)
# Out:
# Company
# Pink Cab       23.162312
# Yellow Cab    110.306849
# Name: Profit, dtype: float64

# %%
# Group by Transaction ID and Company, and calculate the average profit for each group
avg_profit_per_ride_by_cab = final_joined_data.groupby(['Transaction ID', 'Company'])['Profit'].mean().reset_index()

# Print the resulting DataFrame
print(avg_profit_per_ride_by_cab)
# Out:
#         Transaction ID     Company    Profit
# 0             10000011    Pink Cab   57.3150
# 1             10000012    Pink Cab   23.6660
# 2             10000013    Pink Cab   27.5680
# 3             10000014    Pink Cab   25.7980
# 4             10000015    Pink Cab   16.8440
# ...                ...         ...       ...
# 282188        10439842  Yellow Cab  140.3764
# 282189        10439843  Yellow Cab   26.8532
# 282190        10439844  Yellow Cab    9.0088
# 282191        10439845  Yellow Cab  151.8488
# 282192        10439846  Yellow Cab   64.3020
#
# [282193 rows x 3 columns]

# %%
# Assuming you have a DataFrame called 'final_joined_data' with columns 'Company' and 'Profit'
# Assuming you have a DataFrame called 'cab_transaction_data' with transaction information

# Step 1: Calculate total profit for each cab company
total_profit_by_company = final_joined_data.groupby('Company')['Profit'].sum()

# Step 2: Calculate total number of transactions for each cab company
total_transactions_by_company = final_joined_data.groupby('Company')['Transaction ID'].count()

# Step 3: Calculate average profit per ride for each cab company
average_profit_per_ride_by_company = total_profit_by_company / total_transactions_by_company

# Display the results
print("Average Profit per Ride for Each Cab Company:")
print(average_profit_per_ride_by_company)
# Out:
# Average Profit per Ride for Each Cab Company:
# Company
# Pink Cab       64.902195
# Yellow Cab    187.400396
# dtype: float64

# %%
import matplotlib.pyplot as plt

# Assuming 'average_profit_per_ride_by_company' is the Series containing average profit per ride for each cab company

# Plotting
plt.figure(figsize=(10, 6))
average_profit_per_ride_by_company.plot(kind='bar', color=['pink', 'yellow'])
plt.title('Average Profit per Ride for Each Cab Company')
plt.xlabel('Cab Company')
plt.ylabel('Average Profit per Ride')
plt.xticks(rotation=0)  # Rotate x-axis labels for better readability
plt.savefig('Average Profit per Ride for Each Cab Company.png')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt



# Plotting
plt.figure(figsize=(12, 8))
sns.barplot(x='Company', y='Profit', hue='Gender', data=final_joined_data, ci=None)
plt.title('Profit Distribution by Gender for Pink Cab and Yellow Cab')
plt.xlabel('Cab Company')
plt.ylabel('Profit')
plt.savefig('Profit Distribution by Gender for Pink Cab and Yellow Cab.png')
plt.show()

# %%
columns_to_drop = ['Date of Travel','Users','Income Group','Quarter','Month','Day of Week']

# Drop the specified columns
final_joined_data = final_joined_data.drop(columns=columns_to_drop)

# Print the updated DataFrame
print(final_joined_data.head())
# Out:
#         Transaction ID     Company        City  KM Travelled  Price Charged  \
# 0             10000011    Pink Cab  ATLANTA GA         30.45         370.95
# 285625        10351127  Yellow Cab  ATLANTA GA         26.19         598.70
# 336890        10412921  Yellow Cab  ATLANTA GA         42.55         792.05
# 1             10000012    Pink Cab  ATLANTA GA         28.62         358.52
# 261229        10320494  Yellow Cab  ATLANTA GA         36.38         721.10
#
#         Cost of Trip  Customer ID Payment_Mode  Gender  Age  \
# 0           313.6350        29290         Card    Male   47
# 285625      317.4228        29290         Cash    Male   47
# 336890      597.4020        29290         Card    Male   47
# 1           334.8540        27703         Card  Female   36
# 261229      467.1192        27703         Card  Female   36
#
#         Income (USD/Month)  Population    Profit    Age Group  Year  \
# 0                    24297         NaN   57.3150  Middle Aged  1970
# ...

# %%
final_joined_data
# Out:
#         Transaction ID     Company        City  KM Travelled  Price Charged  \
# 0             10000011    Pink Cab  ATLANTA GA         30.45         370.95
# 285625        10351127  Yellow Cab  ATLANTA GA         26.19         598.70
# 336890        10412921  Yellow Cab  ATLANTA GA         42.55         792.05
# 1             10000012    Pink Cab  ATLANTA GA         28.62         358.52
# 261229        10320494  Yellow Cab  ATLANTA GA         36.38         721.10
# ...                ...         ...         ...           ...            ...
# 357421        10437576    Pink Cab   TUCSON AZ         35.96         461.77
# 357424        10437582    Pink Cab   TUCSON AZ         31.35         350.39
# 359155        10439838  Yellow Cab   TUCSON AZ         19.00         303.77
# 359157        10439840  Yellow Cab   TUCSON AZ          5.60          92.42
# 359163        10439846  Yellow Cab   TUCSON AZ         13.30         244.65
#
# ...

# %%
final_joined_data.drop(columns=['Year','Population'])
# Out:
#         Transaction ID     Company        City  KM Travelled  Price Charged  \
# 0             10000011    Pink Cab  ATLANTA GA         30.45         370.95
# 285625        10351127  Yellow Cab  ATLANTA GA         26.19         598.70
# 336890        10412921  Yellow Cab  ATLANTA GA         42.55         792.05
# 1             10000012    Pink Cab  ATLANTA GA         28.62         358.52
# 261229        10320494  Yellow Cab  ATLANTA GA         36.38         721.10
# ...                ...         ...         ...           ...            ...
# 357421        10437576    Pink Cab   TUCSON AZ         35.96         461.77
# 357424        10437582    Pink Cab   TUCSON AZ         31.35         350.39
# 359155        10439838  Yellow Cab   TUCSON AZ         19.00         303.77
# 359157        10439840  Yellow Cab   TUCSON AZ          5.60          92.42
# 359163        10439846  Yellow Cab   TUCSON AZ         13.30         244.65
#
# ...

# %%
total_observations = final_joined_data.shape[0]
print("Total number of observations:", total_observations)
# Out:
# Total number of observations: 282193

# %%
total_features = final_joined_data.shape[1]
print("Total number of features:", total_features)
# Out:
# Total number of features: 17

# %%
file_format = "CSV"  # Replace with the actual file format
print("Base format of the file:", file_format)
# Out:
# Base format of the file: CSV

# %%
size_of_data = final_joined_data.memory_usage(deep=True).sum() / (1024 ** 2)  # Size in megabytes
print("Size of the data:", size_of_data, "MB")
# Out:
# Size of the data: 95.62619209289551 MB

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming 'final_joined_data' is the DataFrame containing the required data

# Define income groups
income_bins = [0, 12000, 25000, 40000, float('inf')]
income_labels = ['0-12k', '12.5k-25k', '25k-40k', '40k+']

# Create a new column 'Income Group' based on income bins
final_joined_data['Income Group'] = pd.cut(final_joined_data['Income (USD/Month)'], bins=income_bins, labels=income_labels)

# Plot the distribution of customers based on income groups for Pink Cab
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
sns.countplot(x='Income Group', data=final_joined_data[final_joined_data['Company'] == 'Pink Cab'], palette='viridis')
plt.title('Pink Cab - Customer Distribution Based on Income Groups')
plt.xlabel('Income Group')
plt.ylabel('Number of Customers')

# Plot the distribution of customers based on income groups for Yellow Cab
plt.subplot(1, 2, 2)
sns.countplot(x='Income Group', data=final_joined_data[final_joined_data['Company'] == 'Yellow Cab'], palette='viridis')
plt.title('Yellow Cab - Customer Distribution Based on Income Groups')
plt.xlabel('Income Group')
plt.ylabel('Number of Customers')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Assuming 'final_joined_data' is the DataFrame containing the required data

# 1. % profit made by both genders for the 2 cabs
gender_profit_percentage = (
    final_joined_data.groupby(['Company', 'Gender'])['Profit']
    .sum()
    .groupby(level=0)
    .apply(lambda x: (x / x.sum()) * 100)
    .reset_index()
)

print("1. % profit made by both genders for the 2 cabs:")
print(gender_profit_percentage)

# 2. % of male and female customers for the 2 cabs
gender_distribution_percentage = (
    final_joined_data.groupby(['Company', 'Gender'])['Customer ID']
    .count()
    .groupby(level=0)
    .apply(lambda x: (x / x.sum()) * 100)
    .reset_index()
)

print("\n2. % of male and female customers for the 2 cabs:")
print(gender_distribution_percentage)

# 3. % profit incurred for each income group for the 2 cabs
income_profit_percentage = (
    final_joined_data.groupby(['Company', 'Income Group'])['Profit']
    .sum()
    .groupby(level=0)
    .apply(lambda x: (x / x.sum()) * 100)
    .reset_index()
)

print("\n3. % profit incurred for each income group for the 2 cabs:")
print(income_profit_percentage)

# 4. % customer distribution for each income Group for the 2 cabs
income_distribution_percentage = (
    final_joined_data.groupby(['Company', 'Income Group'])['Customer ID']
    .count()
    .groupby(level=0)
    .apply(lambda x: (x / x.sum()) * 100)
    .reset_index()
)

print("\n4. % customer distribution for each income group for the 2 cabs:")
print(income_distribution_percentage)

# 5. % profit made across all age groups for the 2 cabs
age_profit_percentage = (
    final_joined_data.groupby(['Company', 'Age Group'])['Profit']
    .sum()
    .groupby(level=0)
    .apply(lambda x: (x / x.sum()) * 100)
    .reset_index()
)

print("\n5. % profit made across all age groups for the 2 cabs:")
print(age_profit_percentage)

# 6. % customer distribution for each age group across the 2 cabs
age_distribution_percentage = (
    final_joined_data.groupby(['Company', 'Age Group'])['Customer ID']
    .count()
    .groupby(level=0)
    .apply(lambda x: (x / x.sum()) * 100)
    .reset_index()
)

print("\n6. % customer distribution for each age group across the 2 cabs:")
print(age_distribution_percentage)

# 7. % profit by city for the 2 cabs
city_profit_percentage = (
    final_joined_data.groupby(['Company', 'City'])['Profit']
    .sum()
    .groupby(level=0)
    .apply(lambda x: (x / x.sum()) * 100)
    .reset_index()
)

print("\n7. % profit by city for the 2 cabs:")
print(city_profit_percentage)

# 8. % customers per city for the 2 cabs
city_distribution_percentage = (
    final_joined_data.groupby(['Company', 'City'])['Customer ID']
    .count()
    .groupby(level=0)
    .apply(lambda x: (x / x.sum()) * 100)
    .reset_index()
)

print("\n8. % customers per city for the 2 cabs:")
print(city_distribution_percentage)

# You can then visualize these percentages using appropriate plots
# For example, bar plots for each category, such as sns.barplot() or plt.bar()
# Out:
# 1. % profit made by both genders for the 2 cabs:
#       Company  Gender     Profit
# 0    Pink Cab  Female  33.237988
# 1    Pink Cab    Male  66.762012
# 2  Yellow Cab  Female  14.960662
# 3  Yellow Cab    Male  85.039338
#
# 2. % of male and female customers for the 2 cabs:
#       Company  Gender  Customer ID
# 0    Pink Cab  Female    38.490802
# 1    Pink Cab    Male    61.509198
# 2  Yellow Cab  Female    25.797374
# 3  Yellow Cab    Male    74.202626
#
# 3. % profit incurred for each income group for the 2 cabs:
#       Company Income Group     Profit
# 0    Pink Cab        0-12k  38.915997
# 1    Pink Cab    12.5k-25k  51.427188
# 2    Pink Cab      25k-40k   9.656815
# 3    Pink Cab         40k+   0.000000
# 4  Yellow Cab        0-12k  39.293270
# 5  Yellow Cab    12.5k-25k  51.195809
# 6  Yellow Cab      25k-40k   9.510921
# 7  Yellow Cab         40k+   0.000000
#
# 4. % customer distribution for each income group for the 2 cabs:
#       Company Income Group  Customer ID
# ...

# %%
# 9. Total km travelled for both cabs
total_km_travelled = final_joined_data.groupby('Company')['KM Travelled'].sum().reset_index()
print("\n9. Total km travelled for both cabs:")
print(total_km_travelled)

# 10. Average profit per km for both cabs
avg_profit_per_km = (
    final_joined_data.groupby('Company')['Profit']
    .sum() / final_joined_data.groupby('Company')['KM Travelled'].sum()
).reset_index(name='Average Profit per KM')
print("\n10. Average profit per km for both cabs:")
print(avg_profit_per_km)

# 11. Average profit per ride for both cabs
avg_profit_per_ride = (
    final_joined_data.groupby('Company')['Profit']
    .sum() / final_joined_data.groupby('Company')['Transaction ID'].nunique()
).reset_index(name='Average Profit per Ride')
print("\n11. Average profit per ride for both cabs:")
print(avg_profit_per_ride)
# Out:
# 9. Total km travelled for both cabs:
#       Company  KM Travelled
# 0    Pink Cab    1659909.11
# 1  Yellow Cab    4705682.45
#
# 10. Average profit per km for both cabs:
#       Company  Average Profit per KM
# 0    Pink Cab               2.877827
# 1  Yellow Cab               8.306986
#
# 11. Average profit per ride for both cabs:
#       Company  Average Profit per Ride
# 0    Pink Cab                64.902195
# 1  Yellow Cab               187.400396

# %%
"""
Exploratory Data Analysis (EDA) Analysis:

% Profit by Gender:

The Pink Cab has a more balanced profit distribution between genders, with females contributing 33.24% and males contributing 66.76%.
The Yellow Cab, however, shows a significant gender-based profit disparity, with females contributing only 14.96%, while males contribute 85.04%.
% Customer Distribution by Gender:

Similar to the profit distribution, the Pink Cab has a more balanced gender distribution among customers, with females constituting 38.49% and males constituting 61.51%.
The Yellow Cab, on the other hand, has a lower percentage of female customers (25.80%) compared to male customers (74.20%).
% Profit by Income Group:

Both Pink and Yellow Cabs have similar profit distribution across income groups.
The highest profit percentage is observed in the income group of 12.5k-25k, followed by the 0-12k income group.
% Customer Distribution by Income Group:

The distribution of customers across income groups is consistent between Pink and Yellow Cabs.
The majority of customers fall into the 0-12k and 12.5k-25k income groups.
% Profit by Age Group:

Pink and Yellow Cabs exhibit similar profit distribution across age groups.
The middle-aged group contributes the most to the profits, followed by the young and old age groups.
% Customer Distribution by Age Group:

Customer distribution across age groups is consistent for both cab companies.
The middle-aged group constitutes the highest percentage of customers, followed by the young and old age groups.
% Profit by City:

New York NY stands out as the most profitable city for both Pink and Yellow Cabs, contributing significantly to their overall profits.
Other cities contribute to varying degrees, but New York NY dominates.
% Customer Distribution by City:

New York NY also has the highest customer distribution for both cab companies, reflecting the correlation between the number of customers and profits.
Total Km Traveled:

Yellow Cab has a significantly higher total distance traveled compared to the Pink Cab.
Average Profit per Km:

Pink Cab has a lower average profit per kilometer compared to the Yellow Cab.
Average Profit per Ride:

Similar to the total profit, Yellow Cab shows a higher average profit per ride compared to the Pink Cab."""

# %%
"""
Recommendation for Investment in Yellow Cab

Based on the analysis of the data provided, I recommend investing in Yellow Cab.

Higher Profitability:

Yellow Cab demonstrates a consistently higher average profit per ride and per kilometer compared to Pink Cab. This suggests better revenue generation and potential for higher returns on investment.
Market Dominance:

Yellow Cab has a significant presence in key markets, especially in cities like New York NY, where it exhibits substantial profitability. Investing in a market leader can provide stability and opportunities for growth.
Diverse Customer Base:

Despite some gender-based profit disparity, Yellow Cab has a broader customer base across income groups and age groups. This diversity may contribute to a more resilient business model.
Potential for Optimization:

With a larger customer base and higher total distance traveled, Yellow Cab has room for potential optimization of operations and services, which could further enhance profitability.
Strategic Growth Opportunities:

The strong performance in New York NY indicates a strategic market presence. The XYZ team can explore opportunities for further growth in this key market and potentially replicate successful strategies in other cities.
